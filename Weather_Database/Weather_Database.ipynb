# %%
# Import the dependencies

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# Import the requests library

import requests

# Import the API key

from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combination

lats = np.random.uniform(-90.000, 90.000, size=2000)

lngs = np.random.uniform(-180.000, 180.000, size=2000)

lats_lngs = zip(lats, lngs)

lats_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
coordinates = list(lats_lngs)

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:

    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)

# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 725

# %%
# Import the time library and the satetime module from the datetime library

import time

from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']

       
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | flinders
# Processing Record 2 of Set 1 | vila franca do campo
# Processing Record 3 of Set 1 | yumen
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | sao filipe
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | karratha
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | balabac
# Processing Record 11 of Set 1 | padang
# Processing Record 12 of Set 1 | tondano
# Processing Record 13 of Set 1 | kununurra
# Processing Record 14 of Set 1 | husavik
# Processing Record 15 of Set 1 | tuma
# Processing Record 16 of Set 1 | wanning
# Processing Record 17 of Set 1 | cidreira
# Processing Record 18 of Set 1 | fortuna
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | mildmay
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | puerto ayacucho
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | sadao
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | lagos
# Processing Record 32 of Set 1 | makakilo city
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | tuatapere
# Processing Record 40 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | lompoc
# Processing Record 43 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 44 of Set 1 | banff
# Processing Record 45 of Set 1 | sioux lookout
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | lyngseidet
# Processing Record 48 of Set 1 | narbonne
# Processing Record 49 of Set 1 | bar-le-duc
# Processing Record 50 of Set 1 | crotone
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | hamilton
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | boca do acre
# Processing Record 7 of Set 2 | ozernovskiy
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | morondava
# Processing Record 10 of Set 2 | tutoia
# Processing Record 11 of Set 2 | saint anthony
# Processing Record 12 of Set 2 | seymchan
# Processing Record 13 of Set 2 | vestmannaeyjar
# Processing Record 14 of Set 2 | cockburn town
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | morant bay
# Processing Record 17 of Set 2 | nazilli
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | grand gaube
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | teshie
# Processing Record 22 of Set 2 | lazaro cardenas
# Processing Record 23 of Set 2 | maningrida
# Processing Record 24 of Set 2 | pitimbu
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | kloulklubed
# Processing Record 29 of Set 2 | myitkyina
# Processing Record 30 of Set 2 | visby
# Processing Record 31 of Set 2 | araouane
# Processing Record 32 of Set 2 | forrest city
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | portalegre
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | quelimane
# Processing Record 39 of Set 2 | geraldton
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | guerrero negro
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | nyurba
# Processing Record 45 of Set 2 | namanyere
# Processing Record 46 of Set 2 | lavrentiya
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 2 | porto santo
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | puerto baquerizo moreno
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | vila
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | perrysburg
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | longyearbyen
# Processing Record 8 of Set 3 | mikuni
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | hvide sande
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | burla
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | bundaberg
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | perelyub
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | salalah
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | adelaide
# Processing Record 23 of Set 3 | pimenta bueno
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | cherskiy
# Processing Record 26 of Set 3 | kamaishi
# Processing Record 27 of Set 3 | fairbanks
# Processing Record 28 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 3 | orlik
# Processing Record 30 of Set 3 | oranjemund
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | krasnomayskiy
# Processing Record 34 of Set 3 | wenling
# Processing Record 35 of Set 3 | souillac
# Processing Record 36 of Set 3 | baruun-urt
# Processing Record 37 of Set 3 | quatre cocos
# Processing Record 38 of Set 3 | bathsheba
# Processing Record 39 of Set 3 | mahebourg
# Processing Record 40 of Set 3 | jackson
# Processing Record 41 of Set 3 | cherbourg
# Processing Record 42 of Set 3 | dunedin
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | hithadhoo
# Processing Record 45 of Set 3 | uyuni
# Processing Record 46 of Set 3 | bethel
# Processing Record 47 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 48 of Set 3 | bria
# Processing Record 49 of Set 3 | tommot
# Processing Record 50 of Set 3 | turbat
# Processing Record 1 of Set 4 | kisanga
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | saint-francois
# Processing Record 4 of Set 4 | santa rosa
# Processing Record 5 of Set 4 | maun
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 4 | brae
# Processing Record 9 of Set 4 | qasigiannguit
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | saint-pierre
# Processing Record 12 of Set 4 | tiznit
# Processing Record 13 of Set 4 | gimbi
# Processing Record 14 of Set 4 | airai
# Processing Record 15 of Set 4 | kaitangata
# Processing Record 16 of Set 4 | auki
# Processing Record 17 of Set 4 | asfi
# Processing Record 18 of Set 4 | atherton
# Processing Record 19 of Set 4 | nogales
# Processing Record 20 of Set 4 | talnakh
# Processing Record 21 of Set 4 | durango
# Processing Record 22 of Set 4 | vanimo
# Processing Record 23 of Set 4 | coutances
# Processing Record 24 of Set 4 | hokitika
# Processing Record 25 of Set 4 | vaini
# Processing Record 26 of Set 4 | beyneu
# Processing Record 27 of Set 4 | suluq
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | omboue
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | ostrovnoy
# Processing Record 32 of Set 4 | noumea
# Processing Record 33 of Set 4 | golpayegan
# Processing Record 34 of Set 4 | yola
# Processing Record 35 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 4 | lahaina
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | hermanus
# Processing Record 39 of Set 4 | kudahuvadhoo
# Processing Record 40 of Set 4 | mattru
# Processing Record 41 of Set 4 | pleshanovo
# Processing Record 42 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 4 | saskylakh
# Processing Record 44 of Set 4 | nishihara
# Processing Record 45 of Set 4 | taoudenni
# Processing Record 46 of Set 4 | todos santos
# Processing Record 47 of Set 4 | novyy urgal
# Processing Record 48 of Set 4 | comodoro rivadavia
# Processing Record 49 of Set 4 | sao joao da barra
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | namatanai
# Processing Record 2 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 5 | provideniya
# Processing Record 4 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 5 | richards bay
# Processing Record 6 of Set 5 | faanui
# Processing Record 7 of Set 5 | usinsk
# Processing Record 8 of Set 5 | aldan
# Processing Record 9 of Set 5 | havoysund
# Processing Record 10 of Set 5 | saint-augustin
# Processing Record 11 of Set 5 | moron
# Processing Record 12 of Set 5 | banjar
# Processing Record 13 of Set 5 | concepcion del uruguay
# Processing Record 14 of Set 5 | te anau
# Processing Record 15 of Set 5 | arnstadt
# Processing Record 16 of Set 5 | okhotsk
# Processing Record 17 of Set 5 | beloha
# Processing Record 18 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 5 | bilma
# Processing Record 20 of Set 5 | fasa
# Processing Record 21 of Set 5 | broken hill
# Processing Record 22 of Set 5 | saldanha
# Processing Record 23 of Set 5 | palmer
# Processing Record 24 of Set 5 | constitucion
# Processing Record 25 of Set 5 | kibala
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | verkhnetulomskiy
# Processing Record 28 of Set 5 | turkmenabat
# Processing Record 29 of Set 5 | ouesso
# Processing Record 30 of Set 5 | arman
# Processing Record 31 of Set 5 | benalla
# Processing Record 32 of Set 5 | praia
# Processing Record 33 of Set 5 | margate
# Processing Record 34 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 5 | voh
# Processing Record 36 of Set 5 | narsaq
# Processing Record 37 of Set 5 | ponta delgada
# Processing Record 38 of Set 5 | akcaabat
# Processing Record 39 of Set 5 | celestun
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | winona
# Processing Record 42 of Set 5 | gravelbourg
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | xaxim
# Processing Record 46 of Set 5 | cairns
# Processing Record 47 of Set 5 | larsnes
# Processing Record 48 of Set 5 | amlimay
# Processing Record 49 of Set 5 | taltal
# Processing Record 50 of Set 5 | palekh
# Processing Record 1 of Set 6 | conceicao do araguaia
# Processing Record 2 of Set 6 | mount isa
# Processing Record 3 of Set 6 | luwuk
# Processing Record 4 of Set 6 | knysna
# Processing Record 5 of Set 6 | laela
# Processing Record 6 of Set 6 | fort dodge
# Processing Record 7 of Set 6 | stende
# Processing Record 8 of Set 6 | lishui
# Processing Record 9 of Set 6 | kahului
# Processing Record 10 of Set 6 | vaitape
# Processing Record 11 of Set 6 | parfenyevo
# Processing Record 12 of Set 6 | victoria point
# Processing Record 13 of Set 6 | viedma
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | port augusta
# Processing Record 16 of Set 6 | norman wells
# Processing Record 17 of Set 6 | sulangan
# Processing Record 18 of Set 6 | namibe
# Processing Record 19 of Set 6 | karachi
# Processing Record 20 of Set 6 | olga
# Processing Record 21 of Set 6 | puerto escondido
# Processing Record 22 of Set 6 | angoche
# Processing Record 23 of Set 6 | teahupoo
# Processing Record 24 of Set 6 | uige
# Processing Record 25 of Set 6 | belize
# Processing Record 26 of Set 6 | nogliki
# Processing Record 27 of Set 6 | lebu
# Processing Record 28 of Set 6 | ballarat
# Processing Record 29 of Set 6 | aviles
# Processing Record 30 of Set 6 | bouna
# Processing Record 31 of Set 6 | acarau
# Processing Record 32 of Set 6 | nanyang
# Processing Record 33 of Set 6 | idlib
# Processing Record 34 of Set 6 | iqaluit
# Processing Record 35 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 6 | naze
# Processing Record 37 of Set 6 | olafsvik
# Processing Record 38 of Set 6 | kruisfontein
# Processing Record 39 of Set 6 | kijang
# Processing Record 40 of Set 6 | port macquarie
# Processing Record 41 of Set 6 | haines junction
# Processing Record 42 of Set 6 | alofi
# Processing Record 43 of Set 6 | hambantota
# Processing Record 44 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 45 of Set 6 | codrington
# Processing Record 46 of Set 6 | kentau
# Processing Record 47 of Set 6 | taormina
# Processing Record 48 of Set 6 | tilichiki
# Processing Record 49 of Set 6 | nouadhibou
# Processing Record 50 of Set 6 | nelson bay
# Processing Record 1 of Set 7 | kavaratti
# Processing Record 2 of Set 7 | plettenberg bay
# Processing Record 3 of Set 7 | eyl
# Processing Record 4 of Set 7 | leua
# Processing Record 5 of Set 7 | gat
# Processing Record 6 of Set 7 | lata
# Processing Record 7 of Set 7 | kota kinabalu
# Processing Record 8 of Set 7 | dongobesh
# Processing Record 9 of Set 7 | raub
# Processing Record 10 of Set 7 | nizwa
# Processing Record 11 of Set 7 | kangaatsiaq
# Processing Record 12 of Set 7 | carballo
# Processing Record 13 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 7 | yerbogachen
# Processing Record 15 of Set 7 | egvekinot
# Processing Record 16 of Set 7 | jieshi
# Processing Record 17 of Set 7 | sobolevo
# Processing Record 18 of Set 7 | port hardy
# Processing Record 19 of Set 7 | havelock
# Processing Record 20 of Set 7 | kontagora
# Processing Record 21 of Set 7 | newport
# Processing Record 22 of Set 7 | chulumani
# Processing Record 23 of Set 7 | srednekolymsk
# Processing Record 24 of Set 7 | cayenne
# Processing Record 25 of Set 7 | buala
# Processing Record 26 of Set 7 | yar-sale
# Processing Record 27 of Set 7 | ukrayinka
# Processing Record 28 of Set 7 | urumqi
# Processing Record 29 of Set 7 | port blair
# Processing Record 30 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 7 | byron bay
# Processing Record 32 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 33 of Set 7 | nantucket
# Processing Record 34 of Set 7 | severo-kurilsk
# Processing Record 35 of Set 7 | vila velha
# Processing Record 36 of Set 7 | kanniyakumari
# Processing Record 37 of Set 7 | kulhudhuffushi
# Processing Record 38 of Set 7 | maniitsoq
# Processing Record 39 of Set 7 | zhuhai
# Processing Record 40 of Set 7 | banda aceh
# Processing Record 41 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 7 | swan hill
# Processing Record 43 of Set 7 | port hedland
# Processing Record 44 of Set 7 | putyatino
# Processing Record 45 of Set 7 | tautira
# Processing Record 46 of Set 7 | tucumcari
# Processing Record 47 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 7 | barranca
# Processing Record 49 of Set 7 | uruguaiana
# Processing Record 50 of Set 7 | goedereede
# Processing Record 1 of Set 8 | areosa
# Processing Record 2 of Set 8 | zafra
# Processing Record 3 of Set 8 | ust-barguzin
# Processing Record 4 of Set 8 | klaksvik
# Processing Record 5 of Set 8 | hakui
# Processing Record 6 of Set 8 | constantine
# Processing Record 7 of Set 8 | erenhot
# Processing Record 8 of Set 8 | pecos
# Processing Record 9 of Set 8 | dingle
# Processing Record 10 of Set 8 | gillette
# Processing Record 11 of Set 8 | feldkirchen
# Processing Record 12 of Set 8 | lorengau
# Processing Record 13 of Set 8 | porto belo
# Processing Record 14 of Set 8 | pauini
# Processing Record 15 of Set 8 | shingu
# Processing Record 16 of Set 8 | puerto narino
# Processing Record 17 of Set 8 | san ignacio
# Processing Record 18 of Set 8 | fort nelson
# Processing Record 19 of Set 8 | goderich
# Processing Record 20 of Set 8 | bonthe
# Processing Record 21 of Set 8 | mastung
# Processing Record 22 of Set 8 | cabedelo
# Processing Record 23 of Set 8 | paamiut
# Processing Record 24 of Set 8 | north battleford
# Processing Record 25 of Set 8 | hazorasp
# Processing Record 26 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 27 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 8 | teguldet
# Processing Record 29 of Set 8 | srandakan
# Processing Record 30 of Set 8 | mecca
# Processing Record 31 of Set 8 | sao jose da coroa grande
# Processing Record 32 of Set 8 | pangkalanbuun
# Processing Record 33 of Set 8 | lac du bonnet
# Processing Record 34 of Set 8 | bhawanigarh
# Processing Record 35 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 8 | varzea da palma
# Processing Record 37 of Set 8 | nome
# Processing Record 38 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 8 | salinopolis
# Processing Record 40 of Set 8 | huarmey
# Processing Record 41 of Set 8 | kautokeino
# Processing Record 42 of Set 8 | kenai
# Processing Record 43 of Set 8 | namanga
# Processing Record 44 of Set 8 | isangel
# Processing Record 45 of Set 8 | pacific grove
# Processing Record 46 of Set 8 | ambon
# Processing Record 47 of Set 8 | leshukonskoye
# Processing Record 48 of Set 8 | roma
# Processing Record 49 of Set 8 | chuy
# Processing Record 50 of Set 8 | sungaipenuh
# Processing Record 1 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 9 | bayir
# Processing Record 4 of Set 9 | port lincoln
# Processing Record 5 of Set 9 | barra do garcas
# Processing Record 6 of Set 9 | manggar
# Processing Record 7 of Set 9 | san vicente
# Processing Record 8 of Set 9 | golden
# Processing Record 9 of Set 9 | rawson
# Processing Record 10 of Set 9 | maua
# Processing Record 11 of Set 9 | vallenar
# Processing Record 12 of Set 9 | kysyl-syr
# Processing Record 13 of Set 9 | san cristobal
# Processing Record 14 of Set 9 | launceston
# Processing Record 15 of Set 9 | college
# Processing Record 16 of Set 9 | hasaki
# Processing Record 17 of Set 9 | hobyo
# Processing Record 18 of Set 9 | oksfjord
# Processing Record 19 of Set 9 | leeuwarden
# Processing Record 20 of Set 9 | guangyuan
# Processing Record 21 of Set 9 | saint george
# Processing Record 22 of Set 9 | mogocha
# Processing Record 23 of Set 9 | gberia fotombu
# Processing Record 24 of Set 9 | belyy yar
# Processing Record 25 of Set 9 | atar
# Processing Record 26 of Set 9 | iguape
# Processing Record 27 of Set 9 | cascais
# Processing Record 28 of Set 9 | nikolayevsk-na-amure
# Processing Record 29 of Set 9 | lerik
# Processing Record 30 of Set 9 | ponta do sol
# Processing Record 31 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 9 | zhezkazgan
# Processing Record 33 of Set 9 | aksarka
# Processing Record 34 of Set 9 | hun
# Processing Record 35 of Set 9 | falakata
# Processing Record 36 of Set 9 | barmer
# Processing Record 37 of Set 9 | tarrafal
# Processing Record 38 of Set 9 | jalu
# Processing Record 39 of Set 9 | antofagasta
# Processing Record 40 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 41 of Set 9 | solwezi
# Processing Record 42 of Set 9 | ust-tsilma
# Processing Record 43 of Set 9 | zlitan
# Processing Record 44 of Set 9 | road town
# Processing Record 45 of Set 9 | ngunguru
# Processing Record 46 of Set 9 | ossora
# Processing Record 47 of Set 9 | santo antonio do sudoeste
# Processing Record 48 of Set 9 | darab
# Processing Record 49 of Set 9 | masuguru
# Processing Record 50 of Set 9 | yining
# Processing Record 1 of Set 10 | saint-joseph
# Processing Record 2 of Set 10 | watrous
# Processing Record 3 of Set 10 | camacha
# Processing Record 4 of Set 10 | kamina
# Processing Record 5 of Set 10 | vardo
# Processing Record 6 of Set 10 | hofn
# Processing Record 7 of Set 10 | avezzano
# Processing Record 8 of Set 10 | shenjiamen
# Processing Record 9 of Set 10 | kralendijk
# Processing Record 10 of Set 10 | isiolo
# Processing Record 11 of Set 10 | aripuana
# Processing Record 12 of Set 10 | walvis bay
# Processing Record 13 of Set 10 | sistranda
# Processing Record 14 of Set 10 | adre
# Processing Record 15 of Set 10 | sayyan
# Processing Record 16 of Set 10 | boa vista
# Processing Record 17 of Set 10 | aykhal
# Processing Record 18 of Set 10 | general roca
# Processing Record 19 of Set 10 | ixtapa
# Processing Record 20 of Set 10 | gayny
# Processing Record 21 of Set 10 | willmar
# Processing Record 22 of Set 10 | san luis
# Processing Record 23 of Set 10 | niquelandia
# Processing Record 24 of Set 10 | tual
# Processing Record 25 of Set 10 | zainsk
# Processing Record 26 of Set 10 | kharakvasla
# Processing Record 27 of Set 10 | amuntai
# Processing Record 28 of Set 10 | halifax
# Processing Record 29 of Set 10 | elesbao veloso
# Processing Record 30 of Set 10 | boddam
# Processing Record 31 of Set 10 | pedasi
# Processing Record 32 of Set 10 | arlit
# Processing Record 33 of Set 10 | mandera
# Processing Record 34 of Set 10 | florianopolis
# Processing Record 35 of Set 10 | darnah
# Processing Record 36 of Set 10 | sorong
# Processing Record 37 of Set 10 | sterling
# Processing Record 38 of Set 10 | mirzapur
# Processing Record 39 of Set 10 | luanda
# Processing Record 40 of Set 10 | loukhi
# Processing Record 41 of Set 10 | sibolga
# Processing Record 42 of Set 10 | canutama
# Processing Record 43 of Set 10 | caravelas
# Processing Record 44 of Set 10 | sorland
# Processing Record 45 of Set 10 | gannan
# Processing Record 46 of Set 10 | aklavik
# Processing Record 47 of Set 10 | ondangwa
# Processing Record 48 of Set 10 | collipulli
# Processing Record 49 of Set 10 | carikar
# City not found. Skipping...
# Processing Record 50 of Set 10 | upington
# Processing Record 1 of Set 11 | port-gentil
# Processing Record 2 of Set 11 | maloh
# Processing Record 3 of Set 11 | karpathos
# Processing Record 4 of Set 11 | los llanos de aridane
# Processing Record 5 of Set 11 | domokos
# Processing Record 6 of Set 11 | marshall
# Processing Record 7 of Set 11 | banga
# Processing Record 8 of Set 11 | zheleznodorozhnyy
# Processing Record 9 of Set 11 | majur
# Processing Record 10 of Set 11 | russell
# Processing Record 11 of Set 11 | lypova dolyna
# Processing Record 12 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 11 | tazovskiy
# Processing Record 14 of Set 11 | portel
# Processing Record 15 of Set 11 | mehamn
# Processing Record 16 of Set 11 | aksu
# Processing Record 17 of Set 11 | kerema
# Processing Record 18 of Set 11 | verkhoyansk
# Processing Record 19 of Set 11 | labuhan
# Processing Record 20 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | bealanana
# Processing Record 22 of Set 11 | beringovskiy
# Processing Record 23 of Set 11 | mitsamiouli
# Processing Record 24 of Set 11 | zyryanovsk
# Processing Record 25 of Set 11 | westport
# Processing Record 26 of Set 11 | berdigestyakh
# Processing Record 27 of Set 11 | yebaishou
# Processing Record 28 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 11 | wlodawa
# Processing Record 30 of Set 11 | san felipe
# Processing Record 31 of Set 11 | tahe
# Processing Record 32 of Set 11 | jumla
# Processing Record 33 of Set 11 | lardos
# Processing Record 34 of Set 11 | kandrian
# Processing Record 35 of Set 11 | tsumeb
# Processing Record 36 of Set 11 | king city
# Processing Record 37 of Set 11 | inhambane
# Processing Record 38 of Set 11 | loandjili
# Processing Record 39 of Set 11 | tovarkovo
# Processing Record 40 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 41 of Set 11 | chapais
# Processing Record 42 of Set 11 | san juan
# Processing Record 43 of Set 11 | sungairaya
# Processing Record 44 of Set 11 | dalby
# Processing Record 45 of Set 11 | la union
# Processing Record 46 of Set 11 | oum hadjer
# Processing Record 47 of Set 11 | carutapera
# Processing Record 48 of Set 11 | buraydah
# Processing Record 49 of Set 11 | adrar
# Processing Record 50 of Set 11 | fevik
# Processing Record 1 of Set 12 | swellendam
# Processing Record 2 of Set 12 | ulaangom
# Processing Record 3 of Set 12 | veinticinco de mayo
# Processing Record 4 of Set 12 | amga
# Processing Record 5 of Set 12 | sokoni
# Processing Record 6 of Set 12 | bud
# Processing Record 7 of Set 12 | marawi
# Processing Record 8 of Set 12 | sacama
# Processing Record 9 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 10 of Set 12 | lukovetskiy
# Processing Record 11 of Set 12 | stokmarknes
# Processing Record 12 of Set 12 | palmerston north
# Processing Record 13 of Set 12 | rogers
# Processing Record 14 of Set 12 | vanavara
# Processing Record 15 of Set 12 | nicoya
# Processing Record 16 of Set 12 | aksha
# Processing Record 17 of Set 12 | muisne
# Processing Record 18 of Set 12 | guacimo
# Processing Record 19 of Set 12 | burica
# City not found. Skipping...
# Processing Record 20 of Set 12 | ayagoz
# Processing Record 21 of Set 12 | nabire
# Processing Record 22 of Set 12 | ucluelet
# Processing Record 23 of Set 12 | leh
# Processing Record 24 of Set 12 | san andres
# Processing Record 25 of Set 12 | griffith
# Processing Record 26 of Set 12 | maltahohe
# Processing Record 27 of Set 12 | narrabri
# Processing Record 28 of Set 12 | tura
# Processing Record 29 of Set 12 | bubaque
# Processing Record 30 of Set 12 | avera
# Processing Record 31 of Set 12 | san jeronimo
# Processing Record 32 of Set 12 | balkanabat
# Processing Record 33 of Set 12 | korla
# Processing Record 34 of Set 12 | shubarkuduk
# Processing Record 35 of Set 12 | nantong
# Processing Record 36 of Set 12 | poso
# Processing Record 37 of Set 12 | tornio
# Processing Record 38 of Set 12 | paraiso
# Processing Record 39 of Set 12 | rincon
# Processing Record 40 of Set 12 | san quintin
# Processing Record 41 of Set 12 | buchanan
# Processing Record 42 of Set 12 | keshan
# City not found. Skipping...
# Processing Record 43 of Set 12 | jabinyanah
# Processing Record 44 of Set 12 | alyangula
# Processing Record 45 of Set 12 | rundu
# Processing Record 46 of Set 12 | manta
# Processing Record 47 of Set 12 | sur
# Processing Record 48 of Set 12 | ugoofaaru
# Processing Record 49 of Set 12 | gari
# Processing Record 50 of Set 12 | deputatskiy
# Processing Record 1 of Set 13 | marathon
# Processing Record 2 of Set 13 | mbala
# Processing Record 3 of Set 13 | thinadhoo
# Processing Record 4 of Set 13 | ketchikan
# Processing Record 5 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 13 | nokaneng
# Processing Record 7 of Set 13 | challakere
# Processing Record 8 of Set 13 | ostuni
# Processing Record 9 of Set 13 | smirnykh
# Processing Record 10 of Set 13 | outjo
# Processing Record 11 of Set 13 | talara
# Processing Record 12 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 13 | ternate
# Processing Record 14 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 15 of Set 13 | santa fe
# Processing Record 16 of Set 13 | kaohsiung
# Processing Record 17 of Set 13 | lityn
# Processing Record 18 of Set 13 | mahanoro
# Processing Record 19 of Set 13 | masaka
# Processing Record 20 of Set 13 | ilhabela
# Processing Record 21 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 22 of Set 13 | bilibino
# Processing Record 23 of Set 13 | soyo
# Processing Record 24 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 13 | luganville
# Processing Record 26 of Set 13 | boyuibe
# Processing Record 27 of Set 13 | ulladulla
# Processing Record 28 of Set 13 | lodja
# Processing Record 29 of Set 13 | suhbaatar
# Processing Record 30 of Set 13 | williston
# Processing Record 31 of Set 13 | kodinar
# Processing Record 32 of Set 13 | nhulunbuy
# Processing Record 33 of Set 13 | claresholm
# Processing Record 34 of Set 13 | marienburg
# Processing Record 35 of Set 13 | hirara
# Processing Record 36 of Set 13 | katangli
# Processing Record 37 of Set 13 | vidalia
# Processing Record 38 of Set 13 | san patricio
# Processing Record 39 of Set 13 | portland
# Processing Record 40 of Set 13 | shilong
# Processing Record 41 of Set 13 | rocha
# Processing Record 42 of Set 13 | belmonte
# Processing Record 43 of Set 13 | batemans bay
# Processing Record 44 of Set 13 | paratebueno
# Processing Record 45 of Set 13 | grindavik
# Processing Record 46 of Set 13 | kouroussa
# Processing Record 47 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 13 | lyuban
# Processing Record 49 of Set 13 | koumac
# Processing Record 50 of Set 13 | thiers
# Processing Record 1 of Set 14 | morbegno
# Processing Record 2 of Set 14 | kedrovyy
# Processing Record 3 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 14 | burnie
# Processing Record 5 of Set 14 | warrenton
# Processing Record 6 of Set 14 | punta de bombon
# Processing Record 7 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 14 | bongouanou
# Processing Record 9 of Set 14 | antsohihy
# Processing Record 10 of Set 14 | gweta
# Processing Record 11 of Set 14 | raga
# Processing Record 12 of Set 14 | tevriz
# Processing Record 13 of Set 14 | skeldon
# Processing Record 14 of Set 14 | peru
# Processing Record 15 of Set 14 | bruck an der leitha
# Processing Record 16 of Set 14 | henties bay
# Processing Record 17 of Set 14 | dustlik
# Processing Record 18 of Set 14 | tocopilla
# Processing Record 19 of Set 14 | gewane
# Processing Record 20 of Set 14 | miri
# Processing Record 21 of Set 14 | vostok
# Processing Record 22 of Set 14 | coahuayana
# Processing Record 23 of Set 14 | santander
# Processing Record 24 of Set 14 | khristoforovo
# City not found. Skipping...
# Processing Record 25 of Set 14 | trinidad
# Processing Record 26 of Set 14 | kieta
# Processing Record 27 of Set 14 | mayo
# Processing Record 28 of Set 14 | karaidel
# Processing Record 29 of Set 14 | tanabe
# Processing Record 30 of Set 14 | calama
# Processing Record 31 of Set 14 | tolaga bay
# Processing Record 32 of Set 14 | concepcion del oro
# Processing Record 33 of Set 14 | porosozero
# Processing Record 34 of Set 14 | dakar
# Processing Record 35 of Set 14 | namasuba
# Processing Record 36 of Set 14 | sumenep
# Processing Record 37 of Set 14 | almeirim
# Processing Record 38 of Set 14 | san policarpo
# Processing Record 39 of Set 14 | gouyave
# Processing Record 40 of Set 14 | dubbo
# Processing Record 41 of Set 14 | samana
# Processing Record 42 of Set 14 | prince rupert
# Processing Record 43 of Set 14 | basco
# Processing Record 44 of Set 14 | seoul
# Processing Record 45 of Set 14 | motala
# Processing Record 46 of Set 14 | nuuk
# Processing Record 47 of Set 14 | xihe
# Processing Record 48 of Set 14 | panjab
# Processing Record 49 of Set 14 | kutum
# Processing Record 50 of Set 14 | trairi
# Processing Record 1 of Set 15 | gravdal
# Processing Record 2 of Set 15 | ilam
# Processing Record 3 of Set 15 | chippewa falls
# Processing Record 4 of Set 15 | valparaiso
# Processing Record 5 of Set 15 | vilyuysk
# Processing Record 6 of Set 15 | evensk
# Processing Record 7 of Set 15 | maues
# Processing Record 8 of Set 15 | rio grande
# Processing Record 9 of Set 15 | san martin
# Processing Record 10 of Set 15 | praia da vitoria
# Processing Record 11 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 12 of Set 15 | zhatay
# Processing Record 13 of Set 15 | morehead
# Processing Record 14 of Set 15 | korhogo
# Processing Record 15 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 16 of Set 15 | chaman
# Processing Record 17 of Set 15 | hami
# Processing Record 18 of Set 15 | thiruvananthapuram
# Processing Record 19 of Set 15 | lagoa
# Processing Record 20 of Set 15 | teluknaga
# Processing Record 21 of Set 15 | general pico
# Processing Record 22 of Set 15 | sao joao
# Processing Record 23 of Set 15 | diego de almagro
# Processing Record 24 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 15 | vondrozo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Flinders -34.5833  150.8552     59.38        71         100
# 1  Vila Franca Do Campo  37.7167  -25.4333     72.01        70          73
# 2                 Yumen  40.2833   97.2000     72.36        22           0
# 3                 Bluff -46.6000  168.3333     41.81        77         100
# 4            Sao Filipe  14.8961  -24.4956     75.72        88          62
# 5                 Kapaa  22.0752 -159.3190     75.18        92         100
# 6              Karratha -20.7377  116.8463     71.83        80           0
# 7               Ushuaia -54.8000  -68.3000     29.86        93         100
# 8           Port Alfred -33.5906   26.8910     60.19        77           0
# 9               Balabac   7.9868  117.0645     82.42        78         100
#
#    Wind Speed Country Current Description
# 0        5.99      AU     overcast clouds
# 1        3.40      PT       broken clouds
# 2       10.87      CN           clear sky
# 3        6.53      NZ     overcast clouds
# 4        7.56      CV       broken clouds
# 5       11.50      US          light rain
# 6        7.38      AU           clear sky
# 7       19.57      AR          heavy snow
# 8        1.01      ZA           clear sky
# 9        3.42      PH     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Flinders      AU -34.5833  150.8552     59.38        71
# 1  Vila Franca Do Campo      PT  37.7167  -25.4333     72.01        70
# 2                 Yumen      CN  40.2833   97.2000     72.36        22
# 3                 Bluff      NZ -46.6000  168.3333     41.81        77
# 4            Sao Filipe      CV  14.8961  -24.4956     75.72        88
# 5                 Kapaa      US  22.0752 -159.3190     75.18        92
# 6              Karratha      AU -20.7377  116.8463     71.83        80
# 7               Ushuaia      AR -54.8000  -68.3000     29.86        93
# 8           Port Alfred      ZA -33.5906   26.8910     60.19        77
# 9               Balabac      PH   7.9868  117.0645     82.42        78
#
#    Cloudiness  Wind Speed Current Description
# 0         100        5.99     overcast clouds
# 1          73        3.40       broken clouds
# 2           0       10.87           clear sky
# 3         100        6.53     overcast clouds
# 4          62        7.56       broken clouds
# 5         100       11.50          light rain
# 6           0        7.38           clear sky
# 7         100       19.57          heavy snow
# 8           0        1.01           clear sky
# 9         100        3.42     overcast clouds

# %%
output_data_file = 'weather_data/WeatherPy_Database.csv'

city_data_df.to_csv(output_data_file, index_label='City_ID')
